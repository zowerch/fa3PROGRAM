# %% [markdown]
# <a href="https://colab.research.google.com/github/zowerch/fa3PROGRAM/blob/main/fa3programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Accept exam score

Score = int(input("Enter student's exam score : "))

# Check if PASSED or FAILED

if Score >= 75:
  print("Passed")
else:
  print("Failed")

# %%
#Ask for student's info
name = input ("Enter Student's name (Surname, First name)" )
age = input ( "Enter student's age" )
course = input ("Enter student's course:" )

#Display formatted info

print("STUDENT'S INFORMATION")
print("name :", name)
print("age :", age)
print("course :", course)

# %%
# Input student info

Name = imput("Enter student's name: ")
Score = input("Enter student's Score: ")

# Determine grade

If 90 <= Score <= 100:
  Grade = "A"
  elif 80 <= Score <= 89:
    Grade = "B"
    elif 70 <= Score <= 79:
      Grade = "C"
      else
      Grade = "F"

      # Display result
Print("GRADE RESULT")
      print("Name :", Name)
      print("Score :", Score)
      print("Grade :", Grade)
